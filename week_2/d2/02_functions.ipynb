# %% [markdown]
# # Functions
#
# <center>
#     <img src = http://s3.amazonaws.com/illustrativemathematics/images/000/000/782/medium/Task_1_8c7a6a9a2e1421586c40f125bd783de3.jpg?1335065782 />
#     </center>

# %%
def hi():
    print('Hello World!')

# %%
hi
# Out:
# <function __main__.hi()>

# %%
hi()
# Out:
# Hello World!

# %% [markdown]
# ### Arguments

# %%
def birth_date(month, day, year):
    bday = str(month) + '/' + str(day) + '/' + str(year)
    print(bday)

# %%
birth_date(month = 11, day = 5, year = 1979)
# Out:
# 11/5/1979

# %%
birth_date(11, 5, 1979)
# Out:
# 11/5/1979

# %% [markdown]
# ##### The `return` statement
#
# We use the `return` statement to return an object to the user after invoking a function.

# %%
#just printing a result
def birth_date(month, day, year):
    bday = str(month) + '/' + str(day) + '/' + str(year)
    print(bday)

# %%
#save and investigate
bdate = birth_date(11, 5, 1979)
type(bdate)
# Out:
# 11/5/1979
# NoneType

# %%
#use return instead
def birth_date(month, day, year):
    bday = str(month) + '/' + str(day) + '/' + str(year)
    return bday
print('steve')
# Out:
# steve

# %%
bdate = birth_date(11, 5, 1979)
type(bdate)
# Out:
# str

# %% [markdown]
# **PROBLEM**
#
#
# <div class="alert alert-primary" role="alert">
#     Fill in the blanks to create a function that takes a list of numbers as an argument and returns the first negative value in the list. What does your function do if the list is empty?
#
# <br>
#     $$~$$
#
# ```python
# def first_negative(values):
#     for v in ____:
#         if ____:
#             return ____
# ```
# </div>

# %%
test_list = [8, 1, -4, 8, -1]

# %%
def first_negative(list_of_numbers):
    '''
    This function takes in a list and 
    returns the first negative number in 
    list.
    
    Arguments
    ---------
    list_of_numbers: list type
    
    Returns
    -------
    int type, smallest value in list
    '''
    #loop over the list of numbers
    for num in list_of_numbers:
        if num < 0: #check if number is negative
            print(num) #print the number
            return num  #return the number

# %%
first_negative(test_list)
# Out:
# -4
# -4

# %%
import random

# %%
random.randint(1, 40)
# Out:
# 29

# %% [markdown]
# The code below will run on a label-printer for chicken eggs. A digital scale will report a chicken egg mass (in grams) to the computer and then the computer will print a label.
#
# Please re-write the code so that the if-block is folded into a function.
#
# ```python
# import random
#  for i in range(10):
#
#     # simulating audience ages
#     age=35+random.randint(1, 40)*-1**i
#
#     print(age)
#
#     #egg sizing machinery prints a label
#     if(age>=65):
#        print("Night Court")
#     elif(age>=50):
#        print("The Bachelor")
#     elif(age<50 and age>=35):
#        print("The Bachelorette")
#     else:
#        print("Seinfeld")
# ```
#
# The simplified program follows. What function definition will make it functional?
#
# ```python
#
# # revised version
# import random
# for i in range(10):
#
#     # simulating audience ages
#     age=35+random.randint(1, 40)*-1**i
#
#     print(age,print_age_label(age))
# ```
#
# 1. Create a function definition for print_age_label() that will work with the revised program above.
# 2. A viewer might be between 18 and 35 or 11 and 18.  Accordingly, we recommend `Last Week Tonight` and `Sportscenter` to each of these groups.  We still want to recommend Seinfeld to anyone we don't have in our brackets.  Modify your function to account for this.

# %% [markdown]
# ### Pandas Library

# %%
import pandas as pd

# %%
import os

# %%
os.listdir('data')
# Out:
# ['gapminder_gdp_americas.csv',
#  'gapminder_gdp_europe.csv',
#  'gapminder_all.csv',
#  'gapminder_gdp_oceania.csv',
#  'gapminder_gdp_africa.csv',
#  'gapminder_gdp_asia.csv']

# %%
data = pd.read_csv('data/gapminder_gdp_oceania.csv')
data
# Out:
#        country  gdpPercap_1952  gdpPercap_1957  gdpPercap_1962  \
# 0    Australia     10039.59564     10949.64959     12217.22686
# 1  New Zealand     10556.57566     12247.39532     13175.67800
#
#    gdpPercap_1967  gdpPercap_1972  gdpPercap_1977  gdpPercap_1982  \
# 0     14526.12465     16788.62948     18334.19751     19477.00928
# 1     14463.91893     16046.03728     16233.71770     17632.41040
#
#    gdpPercap_1987  gdpPercap_1992  gdpPercap_1997  gdpPercap_2002  \
# 0     21888.88903     23424.76683     26997.93657     30687.75473
# 1     19007.19129     18363.32494     21050.41377     23189.80135
#
#    gdpPercap_2007
# 0     34435.36744
# 1     25185.00911

# %%
type(data)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# ### Overview of data with `.info()`

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2 entries, 0 to 1
# Data columns (total 13 columns):
# country           2 non-null object
# gdpPercap_1952    2 non-null float64
# gdpPercap_1957    2 non-null float64
# gdpPercap_1962    2 non-null float64
# gdpPercap_1967    2 non-null float64
# gdpPercap_1972    2 non-null float64
# gdpPercap_1977    2 non-null float64
# gdpPercap_1982    2 non-null float64
# gdpPercap_1987    2 non-null float64
# gdpPercap_1992    2 non-null float64
# gdpPercap_1997    2 non-null float64
# gdpPercap_2002    2 non-null float64
# gdpPercap_2007    2 non-null float64
# dtypes: float64(12), object(1)
# memory usage: 336.0+ bytes

# %%
#columns
data.columns
# Out:
# Index(['country', 'gdpPercap_1952', 'gdpPercap_1957', 'gdpPercap_1962',
#        'gdpPercap_1967', 'gdpPercap_1972', 'gdpPercap_1977', 'gdpPercap_1982',
#        'gdpPercap_1987', 'gdpPercap_1992', 'gdpPercap_1997', 'gdpPercap_2002',
#        'gdpPercap_2007'],
#       dtype='object')

# %%
#describe
data.describe()
# Out:
#        gdpPercap_1952  gdpPercap_1957  gdpPercap_1962  gdpPercap_1967  \
# count        2.000000        2.000000        2.000000        2.000000
# mean     10298.085650    11598.522455    12696.452430    14495.021790
# std        365.560078      917.644806      677.727301       43.986086
# min      10039.595640    10949.649590    12217.226860    14463.918930
# 25%      10168.840645    11274.086022    12456.839645    14479.470360
# 50%      10298.085650    11598.522455    12696.452430    14495.021790
# 75%      10427.330655    11922.958888    12936.065215    14510.573220
# max      10556.575660    12247.395320    13175.678000    14526.124650
#
#        gdpPercap_1972  gdpPercap_1977  gdpPercap_1982  gdpPercap_1987  \
# count         2.00000        2.000000        2.000000        2.000000
# mean      16417.33338    17283.957605    18554.709840    20448.040160
# std         525.09198     1485.263517     1304.328377     2037.668013
# min       16046.03728    16233.717700    17632.410400    19007.191290
# 25%       16231.68533    16758.837652    18093.560120    19727.615725
# 50%       16417.33338    17283.957605    18554.709840    20448.040160
# 75%       16602.98143    17809.077557    19015.859560    21168.464595
# max       16788.62948    18334.197510    19477.009280    21888.889030
#
#        gdpPercap_1992  gdpPercap_1997  gdpPercap_2002  gdpPercap_2007
# count        2.000000        2.000000        2.000000        2.000000
# mean     20894.045885    24024.175170    26938.778040    29810.188275
# std       3578.979883     4205.533703     5301.853680     6540.991104
# min      18363.324940    21050.413770    23189.801350    25185.009110
# 25%      19628.685413    22537.294470    25064.289695    27497.598692
# 50%      20894.045885    24024.175170    26938.778040    29810.188275
# 75%      22159.406358    25511.055870    28813.266385    32122.777857
# max      23424.766830    26997.936570    30687.754730    34435.367440

# %%
data2 = pd.read_csv('data/gapminder_all.csv')

# %%
data2.
# Out:
# Index(['continent', 'country', 'gdpPercap_1952', 'gdpPercap_1957',
#        'gdpPercap_1962', 'gdpPercap_1967', 'gdpPercap_1972', 'gdpPercap_1977',
#        'gdpPercap_1982', 'gdpPercap_1987', 'gdpPercap_1992', 'gdpPercap_1997',
#        'gdpPercap_2002', 'gdpPercap_2007', 'lifeExp_1952', 'lifeExp_1957',
#        'lifeExp_1962', 'lifeExp_1967', 'lifeExp_1972', 'lifeExp_1977',
#        'lifeExp_1982', 'lifeExp_1987', 'lifeExp_1992', 'lifeExp_1997',
#        'lifeExp_2002', 'lifeExp_2007', 'pop_1952', 'pop_1957', 'pop_1962',
#        'pop_1967', 'pop_1972', 'pop_1977', 'pop_1982', 'pop_1987', 'pop_1992',
#        'pop_1997', 'pop_2002', 'pop_2007'],
#       dtype='object')

# %%
data2.shape
# Out:
# (142, 38)

# %%
data.shape
# Out:
# (2, 13)

# %%
data2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 142 entries, 0 to 141
# Data columns (total 38 columns):
# continent         142 non-null object
# country           142 non-null object
# gdpPercap_1952    142 non-null float64
# gdpPercap_1957    142 non-null float64
# gdpPercap_1962    142 non-null float64
# gdpPercap_1967    142 non-null float64
# gdpPercap_1972    142 non-null float64
# gdpPercap_1977    142 non-null float64
# gdpPercap_1982    142 non-null float64
# gdpPercap_1987    142 non-null float64
# gdpPercap_1992    142 non-null float64
# gdpPercap_1997    142 non-null float64
# gdpPercap_2002    142 non-null float64
# gdpPercap_2007    142 non-null float64
# lifeExp_1952      142 non-null float64
# lifeExp_1957      142 non-null float64
# lifeExp_1962      142 non-null float64
# lifeExp_1967      142 non-null float64
# lifeExp_1972      142 non-null float64
# lifeExp_1977      142 non-null float64
# lifeExp_1982      142 non-null float64
# lifeExp_1987      142 non-null float64
# lifeExp_1992      142 non-null float64
# lifeExp_1997      142 non-null float64
# lifeExp_2002      142 non-null float64
# lifeExp_2007      142 non-null float64
# pop_1952          142 non-null float64
# pop_1957          142 non-null float64
# pop_1962          142 non-null float64
# pop_1967          142 non-null float64
# pop_1972          142 non-null float64
# pop_1977          142 non-null float64
# pop_1982          142 non-null float64
# pop_1987          142 non-null float64
# pop_1992          142 non-null float64
# pop_1997          142 non-null float64
# pop_2002          142 non-null int64
# pop_2007          142 non-null int64
# dtypes: float64(34), int64(2), object(2)
# memory usage: 42.3+ KB

# %% [markdown]
# **PROBLEMS**
#
# 1. Read in `gapminder_gdp_americas.csv` and bind to variable `americas`.  Display the summary statistics.

# %%
americas = pd.read_csv('data/gapminder_gdp_americas.csv')

# %%
americas.describe()
# Out:
#        gdpPercap_1952  gdpPercap_1957  gdpPercap_1962  gdpPercap_1967  \
# count       25.000000       25.000000       25.000000       25.000000
# mean      4079.062552     4616.043733     4901.541870     5668.253496
# std       3001.727522     3312.381083     3421.740569     4160.885560
# min       1397.717137     1544.402995     1662.137359     1452.057666
# 25%       2428.237769     2487.365989     2750.364446     3242.531147
# 50%       3048.302900     3780.546651     4086.114078     4643.393534
# 75%       3939.978789     4756.525781     5180.755910     5788.093330
# max      13990.482080    14847.127120    16173.145860    19530.365570
#
#        gdpPercap_1972  gdpPercap_1977  gdpPercap_1982  gdpPercap_1987  \
# count       25.000000       25.000000       25.000000       25.000000
# mean      6491.334139     7352.007126     7506.737088     7793.400261
# std       4754.404329     5355.602518     5530.490471     6665.039509
# min       1654.456946     1874.298931     2011.159549     1823.015995
# 25%       4031.408271     4756.763836     4258.503604     4140.442097
# 50%       5305.445256     6281.290855     6434.501797     6360.943444
# 75%       6809.406690     7674.929108     8997.897412     7807.095818
# max      21806.035940    24072.632130    25009.559140    29884.350410
#
#        gdpPercap_1992  gdpPercap_1997  gdpPercap_2002  gdpPercap_2007
# count       25.000000       25.000000       25.000000       25.000000
# mean      8044.934406     8889.300863     9287.677107    11003.031625
# std       7047.089191     7874.225145     8895.817785     9713.209302
# min       1456.309517     1341.726931     1270.364932     1201.637154
# 25%       4439.450840     4684.313807     4858.347495     5728.353514
# 50%       6618.743050     7113.692252     6994.774861     8948.102923
# 75%       8137.004775     9767.297530     8797.640716    11977.574960
# max      32003.932240    35767.433030    39097.099550    42951.653090

# %% [markdown]
# 2. What does the `.head()` and `.tail()` method do?  (Try it out with `americas.head()` or `americas.tail()`.

# %%
americas.head(3)
# Out:
#   continent    country  gdpPercap_1952  gdpPercap_1957  gdpPercap_1962  \
# 0  Americas  Argentina     5911.315053     6856.856212     7133.166023
# 1  Americas    Bolivia     2677.326347     2127.686326     2180.972546
# 2  Americas     Brazil     2108.944355     2487.365989     3336.585802
#
#    gdpPercap_1967  gdpPercap_1972  gdpPercap_1977  gdpPercap_1982  \
# 0     8052.953021     9443.038526    10079.026740     8997.897412
# 1     2586.886053     2980.331339     3548.097832     3156.510452
# 2     3429.864357     4985.711467     6660.118654     7030.835878
#
#    gdpPercap_1987  gdpPercap_1992  gdpPercap_1997  gdpPercap_2002  \
# 0     9139.671389     9308.418710    10967.281950     8797.640716
# 1     2753.691490     2961.699694     3326.143191     3413.262690
# 2     7807.095818     6950.283021     7957.980824     8131.212843
#
#    gdpPercap_2007
# 0    12779.379640
# 1     3822.137084
# 2     9065.800825

# %%
americas.tail(10)
# Out:
#    continent              country  gdpPercap_1952  gdpPercap_1957  \
# 15  Americas               Mexico     3478.125529     4131.546641
# 16  Americas            Nicaragua     3112.363948     3457.415947
# 17  Americas               Panama     2480.380334     2961.800905
# 18  Americas             Paraguay     1952.308701     2046.154706
# 19  Americas                 Peru     3758.523437     4245.256698
# 20  Americas          Puerto Rico     3081.959785     3907.156189
# 21  Americas  Trinidad and Tobago     3023.271928     4100.393400
# 22  Americas        United States    13990.482080    14847.127120
# 23  Americas              Uruguay     5716.766744     6150.772969
# 24  Americas            Venezuela     7689.799761     9802.466526
#
#     gdpPercap_1962  gdpPercap_1967  gdpPercap_1972  gdpPercap_1977  \
# 15     4581.609385     5754.733883     6809.406690     7674.929108
# 16     3634.364406     4643.393534     4688.593267     5486.371089
# 17     3536.540301     4421.009084     5364.249663     5351.912144
# 18     2148.027146     2299.376311     2523.337977     3248.373311
# 19     4957.037982     5788.093330     5937.827283     6281.290855
# 20     5108.344630     6929.277714     9123.041742     9770.524921
# 21     4997.523971     5621.368472     6619.551419     7899.554209
# 22    16173.145860    19530.365570    21806.035940    24072.632130
# 23     5603.357717     5444.619620     5703.408898     6504.339663
# 24     8422.974165     9541.474188    10505.259660    13143.950950
#
#     gdpPercap_1982  gdpPercap_1987  gdpPercap_1992  gdpPercap_1997  \
# 15     9611.147541     8688.156003     9472.384295     9767.297530
# 16     3470.338156     2955.984375     2170.151724     2253.023004
# 17     7009.601598     7034.779161     6618.743050     7113.692252
# 18     4258.503604     3998.875695     4196.411078     4247.400261
# 19     6434.501797     6360.943444     4446.380924     5838.347657
# 20    10330.989150    12281.341910    14641.587110    16999.433300
# 21     9119.528607     7388.597823     7370.990932     8792.573126
# 22    25009.559140    29884.350410    32003.932240    35767.433030
# 23     6920.223051     7452.398969     8137.004775     9230.240708
# 24    11152.410110     9883.584648    10733.926310    10165.495180
#
#     gdpPercap_2002  gdpPercap_2007
# 15    10742.440530    11977.574960
# 16     2474.548819     2749.320965
# 17     7356.031934     9809.185636
# 18     3783.674243     4172.838464
# 19     5909.020073     7408.905561
# 20    18855.606180    19328.709010
# 21    11460.600230    18008.509240
# 22    39097.099550    42951.653090
# 23     7727.002004    10611.462990
# 24     8605.047831    11415.805690

# %% [markdown]
# ### Basic Data Analysis
#
# - Select columns
# - Select rows
# - Select subsets of columns
# - Select subsets of rows
# - Select elements based on conditions

# %%
#read in data in gapminder_all.csv
gap_all = pd.read_csv('data/gapminder_all.csv')

# %%
#examine data
gap_all.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 142 entries, 0 to 141
# Data columns (total 38 columns):
# continent         142 non-null object
# country           142 non-null object
# gdpPercap_1952    142 non-null float64
# gdpPercap_1957    142 non-null float64
# gdpPercap_1962    142 non-null float64
# gdpPercap_1967    142 non-null float64
# gdpPercap_1972    142 non-null float64
# gdpPercap_1977    142 non-null float64
# gdpPercap_1982    142 non-null float64
# gdpPercap_1987    142 non-null float64
# gdpPercap_1992    142 non-null float64
# gdpPercap_1997    142 non-null float64
# gdpPercap_2002    142 non-null float64
# gdpPercap_2007    142 non-null float64
# lifeExp_1952      142 non-null float64
# lifeExp_1957      142 non-null float64
# lifeExp_1962      142 non-null float64
# lifeExp_1967      142 non-null float64
# lifeExp_1972      142 non-null float64
# lifeExp_1977      142 non-null float64
# lifeExp_1982      142 non-null float64
# lifeExp_1987      142 non-null float64
# lifeExp_1992      142 non-null float64
# lifeExp_1997      142 non-null float64
# lifeExp_2002      142 non-null float64
# lifeExp_2007      142 non-null float64
# pop_1952          142 non-null float64
# pop_1957          142 non-null float64
# pop_1962          142 non-null float64
# pop_1967          142 non-null float64
# pop_1972          142 non-null float64
# pop_1977          142 non-null float64
# pop_1982          142 non-null float64
# pop_1987          142 non-null float64
# pop_1992          142 non-null float64
# pop_1997          142 non-null float64
# pop_2002          142 non-null int64
# pop_2007          142 non-null int64
# dtypes: float64(34), int64(2), object(2)
# memory usage: 42.3+ KB

# %%
#select country column
gap_all['country']
# Out:
# 0             Algeria
# 1              Angola
# 2               Benin
# 3            Botswana
# 4        Burkina Faso
#             ...
# 137       Switzerland
# 138            Turkey
# 139    United Kingdom
# 140         Australia
# 141       New Zealand
# Name: country, Length: 142, dtype: object

# %%
#select country and continents

gap_all[['country', 'continent']]
# Out:
#             country continent
# 0           Algeria    Africa
# 1            Angola    Africa
# 2             Benin    Africa
# 3          Botswana    Africa
# 4      Burkina Faso    Africa
# ..              ...       ...
# 137     Switzerland    Europe
# 138          Turkey    Europe
# 139  United Kingdom    Europe
# 140       Australia   Oceania
# 141     New Zealand   Oceania
#
# [142 rows x 2 columns]

# %%
#select rows by index
gap_all.iloc[10:13]
# Out:
#    continent          country  gdpPercap_1952  gdpPercap_1957  gdpPercap_1962  \
# 10    Africa  Congo Dem. Rep.      780.542326      905.860230      896.314634
# 11    Africa       Congo Rep.     2125.621418     2315.056572     2464.783157
# 12    Africa    Cote d'Ivoire     1388.594732     1500.895925     1728.869428
#
#     gdpPercap_1967  gdpPercap_1972  gdpPercap_1977  gdpPercap_1982  \
# 10      861.593242      904.896069      795.757282      673.747818
# 11     2677.939642     3213.152683     3259.178978     4879.507522
# 12     2052.050473     2378.201111     2517.736547     2602.710169
#
#     gdpPercap_1987  ...    pop_1962    pop_1967    pop_1972    pop_1977  \
# 10      672.774812  ...  17486434.0  19941073.0  23007669.0  26480870.0
# 11     4201.194937  ...   1047924.0   1179760.0   1340458.0   1536769.0
# 12     2156.956069  ...   3832408.0   4744870.0   6071696.0   7459574.0
#
#       pop_1982    pop_1987    pop_1992    pop_1997  pop_2002  pop_2007
# 10  30646495.0  35481645.0  41672143.0  47798986.0  55379852  64606759
# 11   1774735.0   2064095.0   2409073.0   2800947.0   3328795   3800610
# 12   9025951.0  10761098.0  12772596.0  14625967.0  16252726  18013409
#
# [3 rows x 38 columns]

# %%
#select rows by condition
gap_all.loc[gap_all['continent'] == 'Africa']
# Out:
#    continent                   country  gdpPercap_1952  gdpPercap_1957  \
# 0     Africa                   Algeria     2449.008185     3013.976023
# 1     Africa                    Angola     3520.610273     3827.940465
# 2     Africa                     Benin     1062.752200      959.601080
# 3     Africa                  Botswana      851.241141      918.232535
# 4     Africa              Burkina Faso      543.255241      617.183465
# 5     Africa                   Burundi      339.296459      379.564628
# 6     Africa                  Cameroon     1172.667655     1313.048099
# 7     Africa  Central African Republic     1071.310713     1190.844328
# 8     Africa                      Chad     1178.665927     1308.495577
# 9     Africa                   Comoros     1102.990936     1211.148548
# 10    Africa           Congo Dem. Rep.      780.542326      905.860230
# 11    Africa                Congo Rep.     2125.621418     2315.056572
# 12    Africa             Cote d'Ivoire     1388.594732     1500.895925
# 13    Africa                  Djibouti     2669.529475     2864.969076
# 14    Africa                     Egypt     1418.822445     1458.915272
# 15    Africa         Equatorial Guinea      375.643123      426.096408
# 16    Africa                   Eritrea      328.940557      344.161886
# 17    Africa                  Ethiopia      362.146280      378.904163
# 18    Africa                     Gabon     4293.476475     4976.198099
# 19    Africa                    Gambia      485.230659      520.926711
# 20    Africa                     Ghana      911.298937     1043.561537
# 21    Africa                    Guinea      510.196492      576.267025
# 22    Africa             Guinea-Bissau      299.850319      431.790457
# 23    Africa                     Kenya      853.540919      944.438315
# 24    Africa                   Lesotho      298.846212      335.997115
# 25    Africa                   Liberia      575.572996      620.969990
# 26    Africa                     Libya     2387.548060     3448.284395
# 27    Africa                Madagascar     1443.011715     1589.202750
# 28    Africa                    Malawi      369.165080      416.369806
# 29    Africa                      Mali      452.336981      490.382187
# 30    Africa                Mauritania      743.115910      846.120261
# 31    Africa                 Mauritius     1967.955707     2034.037981
# 32    Africa                   Morocco     1688.203570     1642.002314
# 33    Africa                Mozambique      468.526038      495.586833
# 34    Africa                   Namibia     2423.780443     2621.448058
# 35    Africa                     Niger      761.879376      835.523403
# 36    Africa                   Nigeria     1077.281856     1100.592563
# 29   6491649.0   6998256.0   7634008.0   8416215.0    9384984.0   10580176
# 30   1456688.0   1622136.0   1841240.0   2119465.0    2444741.0    2828858
# 31    913025.0    992040.0   1042663.0   1096202.0    1149818.0    1200206
# 32  18396941.0  20198730.0  22987397.0  25798239.0   28529501.0   31167783
# 33  11127868.0  12587223.0  12891952.0  13160731.0   16603334.0   18473780
# 34    977026.0   1099010.0   1278184.0   1554253.0    1774766.0    1972153
# 35   5682086.0   6437188.0   7332638.0   8392818.0    9666252.0   11140655
# 36  62209173.0  73039376.0  81551520.0  93364244.0  106207839.0  119901274
# 37    492095.0    517810.0    562035.0    622191.0     684810.0     743981
# 38   4657072.0   5507565.0   6349365.0   7290203.0    7212583.0    7852401
# 39     86796.0     98593.0    110812.0    125911.0     145608.0     170372
# 40   5260855.0   6147783.0   7171347.0   8307920.0    9535314.0   10870037
# 41   3140897.0   3464522.0   3868905.0   4260884.0    4578212.0    5359092
# 42   4353666.0   5828892.0   6921858.0   6099799.0    6633514.0    7753310
# 43  27129932.0  31140029.0  35933379.0  39964159.0   42835005.0   44433622
# 44  17104986.0  20367053.0  24725960.0  28227588.0   32160729.0   37090298
# 45    551425.0    649901.0    779348.0    962344.0    1054486.0    1130269
# 46  17129565.0  19844382.0  23040630.0  26605473.0   30686889.0   34593779
# 47   2308582.0   2644765.0   3154264.0   3747553.0    4320890.0    4977378
# 48   6005061.0   6734098.0   7724976.0   8523077.0    9231669.0    9770575
# 49  11457758.0  12939400.0  15283050.0  18252190.0   21210254.0   24739869
# 50   5216550.0   6100407.0   7272406.0   8381163.0    9417789.0   10595811
# 51   6642107.0   7636524.0   9216418.0  10704340.0   11404948.0   11926563
#
#      pop_2007
# 0    33333216
# 1    12420476
# 2     8078314
# 3     1639131
# 4    14326203
# 5     8390505
# 6    17696293
# 7     4369038
# 8    10238807
# 9      710960
# 10   64606759
# 11    3800610
# 12   18013409
# 13     496374
# 14   80264543
# 15     551201
# 16    4906585
# 17   76511887
# 18    1454867
# 19    1688359
# 20   22873338
# 21    9947814
# 22    1472041
# 23   35610177
# 24    2012649
# 25    3193942
# 26    6036914
# 27   19167654
# 28   13327079
# 29   12031795
# 30    3270065
# 31    1250882
# 32   33757175
# 33   19951656
# 34    2055080
# 35   12894865
# 36  135031164
# 37     798094
# 38    8860588
# 39     199579
# 40   12267493
# 41    6144562
# 42    9118773
# 43   43997828
# 44   42292929
# 45    1133066
# 46   38139640
# 47    5701579
# 48   10276158
# 49   29170398
# 50   11746035
# 51   12311143
#
# [52 rows x 38 columns]

# %%
#rows by condition and selected columns

# %%
#read in europe with country as index

# %%
#select all rows for some country

# %%
import pandas as pd

df = pd.read_csv('data/gapminder_gdp_europe.csv', index_col='country')

# %% [markdown]
# 1. Write an expression for the Per Capita GDP of Serbia in 2007

# %% [markdown]
# 1. Do the two statements below produce the same output?
# 2. Based on this, what rule governs what is included (or not) in numerical slices and named slices in Pandas?
#
# ```python
# print(df.iloc[0:2, 0:2])
# print(df.loc['Albania':'Belgium', 'gdpPercap_1952':'gdpPercap_1962'])
# ```

# %% [markdown]
# 3. Write comments in the following program to explain what each line does.

# %%
first = pd.read_csv('data/gapminder_all.csv', index_col='country')
second = first[first['continent'] == 'Americas']
third = second.drop('Puerto Rico')
fourth = third.drop('continent', axis = 1)
fourth.to_csv('result.csv')

# %% [markdown]
# Import the gapminder data for Europe and write an expression to select each of the following:
#
# - GDP per capita for all countries in 1982.
# - GDP per capita for Denmark for all years.
# - GDP per capita for all countries for years after 1985.
# - GDP per capita for each country in 2007 as a multiple of GDP per capita for that country in 1952.

# %%
#GDP per capita for all countries in 1982.

# %%
#GDP per capita for Denmark for all years.

# %%
#GDP per capita for all countries for years after 1985.

# %%
#GDP per capita for each country in 2007 as a 
#multiple of GDP per capita for that country in 1952.

# %% [markdown]
# ### Looping over data

# %%
import pandas as pd
for filename in ['data/gapminder_gdp_africa.csv', 'data/gapminder_gdp_asia.csv']:
    data = pd.read_csv(filename, index_col='country')
    print(filename, data.min())
# Out:
# data/gapminder_gdp_africa.csv gdpPercap_1952    298.846212
# gdpPercap_1957    335.997115
# gdpPercap_1962    355.203227
# gdpPercap_1967    412.977514
# gdpPercap_1972    464.099504
# gdpPercap_1977    502.319733
# gdpPercap_1982    462.211415
# gdpPercap_1987    389.876185
# gdpPercap_1992    410.896824
# gdpPercap_1997    312.188423
# gdpPercap_2002    241.165877
# gdpPercap_2007    277.551859
# dtype: float64
# data/gapminder_gdp_asia.csv gdpPercap_1952    331.0
# gdpPercap_1957    350.0
# gdpPercap_1962    388.0
# gdpPercap_1967    349.0
# gdpPercap_1972    357.0
# gdpPercap_1977    371.0
# gdpPercap_1982    424.0
# gdpPercap_1987    385.0
# gdpPercap_1992    347.0
# gdpPercap_1997    415.0
# gdpPercap_2002    611.0
# gdpPercap_2007    944.0
# dtype: float64

# %%
import glob

# %%
#list all files matching
glob.glob('data/*.csv')
# Out:
# ['data/gapminder_gdp_americas.csv',
#  'data/gapminder_gdp_europe.csv',
#  'data/gapminder_all.csv',
#  'data/gapminder_gdp_oceania.csv',
#  'data/gapminder_gdp_africa.csv',
#  'data/gapminder_gdp_asia.csv']

# %%
#loop over files
for filename in glob.glob('data/gapminder_*.csv'):
    df = pd.read_csv(filename)
    print(filename, df['gdpPercap_1952'].min())
# Out:
# data/gapminder_gdp_americas.csv 1397.7171369999999
# data/gapminder_gdp_europe.csv 973.5331947999999
# data/gapminder_all.csv 298.8462121
# data/gapminder_gdp_oceania.csv 10039.595640000001
# data/gapminder_gdp_africa.csv 298.8462121
# data/gapminder_gdp_asia.csv 331.0

# %%
#putting it together with a function
def gdp_min(dataframe):
    return dataframe['gdpPercap_1952'].min()

# %%
#write it in file
import gdp

# %%
for filename in glob.glob('data/gapminder_*.csv'):
    df = pd.read_csv(filename)
    print(filename, gdp.gdp_min(df))
# Out:
# data/gapminder_gdp_americas.csv 1397.7171369999999
# data/gapminder_gdp_europe.csv 973.5331947999999
# data/gapminder_all.csv 298.8462121
# data/gapminder_gdp_oceania.csv 10039.595640000001
# data/gapminder_gdp_africa.csv 298.8462121
# data/gapminder_gdp_asia.csv 331.0

# %% [markdown]
# ### PROBLEM
#
# Write a program that loops over the files and creates a dictionary with a "year", "continent", "country", and "gdp" key and tracks the highest gdp per each year.

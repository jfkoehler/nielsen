# %% [markdown]
# # Finalizing a Graphic
#
# Things to consider:
#
# - data-ink ratio
# - chartjunk

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns

# %%
nyc_311 = pd.read_json('https://data.cityofnewyork.us/resource/erm2-nwe9.json')

# %%
complainers = nyc_311['borough'].value_counts().nlargest(6)

# %%
plt.bar(complainers.index, complainers)
# Out:
# <BarContainer object of 6 artists>

# %%
plt.bar(complainers.index, complainers)
# remove all the ticks (both axes), and tick labels on the Y axis
plt.tick_params(top='off', bottom='off', left='off', right='off', labelleft='off', labelbottom='on')

for spine in plt.gca().spines.values():
    spine.set_visible(False)
plt.xticks(rotation = 90)
# Out:
# ([0, 1, 2, 3, 4, 5], <a list of 6 Text xticklabel objects>)

# %%
plt.figure()
plt.bar(complainers.index, complainers)
plt.xticks(np.arange(6), complainers.index)
# remove all the ticks (both axes), and tick labels on the Y axis
plt.tick_params(top='off', left='off', bottom = 'off', right='off', labelleft='off', labelbottom='on')

for spine in plt.gca().spines.values():
    spine.set_visible(False)
plt.xticks(rotation = 90);

plt.yticks([])
# Out:
# ([], <a list of 0 Text yticklabel objects>)

# %%
plt.figure()
bars = plt.bar(complainers.index, complainers)
plt.xticks(np.arange(6), complainers.index)
# remove all the ticks (both axes), and tick labels on the Y axis
plt.tick_params(top='off', left='off', bottom = 'off', right='off', labelleft='off', labelbottom='on')

for spine in plt.gca().spines.values():
    spine.set_visible(False)
plt.xticks(rotation = 90);

plt.yticks([])
for bar in bars:
    plt.gca().text(bar.get_x() + bar.get_width()/2, bar.get_height() - 15, str(int(bar.get_height())), 
                 ha='center', color='w', fontsize=11)

# %%
plt.figure(figsize = (10, 5))
colors = ['lightblue'] + ['grey']*(len(complainers.index)-1)

bars = plt.bar(complainers.index, complainers, color = colors)


# remove all the ticks (both axes), and tick labels on the Y axis
plt.tick_params(top='off', left='off', bottom = 'off', right='off', labelleft='off', labelbottom='on')


for spine in plt.gca().spines.values():
    spine.set_visible(False)
plt.xticks(rotation = 90);

plt.yticks([])
for bar in bars:
    plt.gca().text(bar.get_x() + bar.get_width()/2, bar.get_height() - 25, str(int(bar.get_height())), 
                 ha='center', color='w', fontsize=11)
plt.title("Who's been calling 311", loc = 'left', fontsize = 14);

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %% [markdown]
# # Visualizing with `pyplot`

# %%
import seaborn as sns
tips = sns.load_dataset('tips')

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
#default plot of numeric data
tips.plot()

# %%
#plot a single quantitative feature
tips['total_bill'].plot()

# %%
#adjust the kind of plot
tips['total_bill'].plot(kind = 'hist')

# %%
#same as using pyplot directly
plt.hist(tips['total_bill'])
# Out:
# (array([ 7., 42., 68., 51., 31., 19., 12.,  7.,  3.,  4.]),
#  array([ 3.07 ,  7.844, 12.618, 17.392, 22.166, 26.94 , 31.714, 36.488,
#         41.262, 46.036, 50.81 ]),
#  <a list of 10 Patch objects>)

# %%
#using additional arguments
tips['total_bill'].plot(kind = 'density', title = 'A Density Plot')

# %%
#plot results of aggregation
tips.groupby('smoker')['total_bill'].mean().plot(kind = 'bar')

# %%
pd.pivot_table(tips, values = 'total_bill', index = 'day', columns = 'smoker',
        aggfunc = np.sum)
# Out:
# smoker     Yes       No
# day
# Thur    326.24   770.09
# Fri     252.20    73.68
# Sat     893.62   884.78
# Sun     458.28  1168.88

# %%
pd.pivot_table(tips, values = 'total_bill', index = 'day', columns = 'smoker').plot(kind = 'bar')

# %% [markdown]
# ##### PROBLEMS

# %%
titanic = sns.load_dataset('titanic')

# %%
titanic.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
titanic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 15 columns):
# survived       891 non-null int64
# pclass         891 non-null int64
# sex            891 non-null object
# age            714 non-null float64
# sibsp          891 non-null int64
# parch          891 non-null int64
# fare           891 non-null float64
# embarked       889 non-null object
# class          891 non-null category
# who            891 non-null object
# adult_male     891 non-null bool
# deck           203 non-null category
# embark_town    889 non-null object
# alive          891 non-null object
# alone          891 non-null bool
# dtypes: bool(2), category(2), float64(2), int64(4), object(5)
# memory usage: 80.6+ KB

# %% [markdown]
# ##### Problems
#
# 1. Visualize the difference in survival of men and women.
# 2. Visualize the difference in survival based on the `pclass` column.
# 3. Create a scatter plot of age vs. fare using `plt.scatter`.
# 4. Load in the `gapminder_all.csv` data in the data folder.  Create a plot of the gdp vs. life expectancy for a given year.  5. Use the plot above and add in a size argument based on the population.  Scale it so the point size is reasonable.
# 6. Write a function to map a list of colors to each continent, create a new column named color and map the continents to color values.
# 7. Using the scatter plot with population size, include colors for each continent and a legend element.

# %% [markdown]
# # Missing Data and Merging Data

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %% [markdown]
# ### Handling Missing Data

# %%
data = pd.DataFrame({'col_1': ['a', 'b', np.nan, 'c', None]})

# %%
data
# Out:
#   col_1
# 0     a
# 1     b
# 2   NaN
# 3     c
# 4  None

# %%
#nan and None are both treated as null
data.isnull()
# Out:
#    col_1
# 0  False
# 1  False
# 2   True
# 3  False
# 4   True

# %%
#quick view of null counts
data.isnull().sum()
# Out:
# col_1    2
# dtype: int64

# %%
#drop the null
data.dropna()
# Out:
#   col_1
# 0     a
# 1     b
# 3     c

# %% [markdown]
# ##### Controlling the drop

# %%
data = pd.DataFrame({'a': [1, 2, np.nan, None],
                    'b': [6, np.nan, None, 3.4],
                    'c': [4, np.nan, np.nan, np.nan],
                    'd': [3, np.nan, np.nan, 8]})

# %%
data
# Out:
#      a    b    c    d
# 0  1.0  6.0  4.0  3.0
# 1  2.0  NaN  NaN  NaN
# 2  NaN  NaN  NaN  NaN
# 3  NaN  3.4  NaN  8.0

# %%
#default is any row with missing values
data.dropna()
# Out:
#      a    b    c    d
# 0  1.0  6.0  4.0  3.0

# %%
#only if all data is missing
data.dropna(how = 'all')
# Out:
#      a    b    c    d
# 0  1.0  6.0  4.0  3.0
# 1  2.0  NaN  NaN  NaN
# 3  NaN  3.4  NaN  8.0

# %%
data['d'] = np.nan

# %%
data
# Out:
#      a    b    c   d
# 0  1.0  6.0  4.0 NaN
# 1  2.0  NaN  NaN NaN
# 2  NaN  NaN  NaN NaN
# 3  NaN  3.4  NaN NaN

# %%
#drop based on columns
data.dropna(axis = 1)
# Out:
# Empty DataFrame
# Columns: []
# Index: [0, 1, 2, 3]

# %%
#only columns with all data missing
data.dropna(axis = 1, how = 'all')
# Out:
#      a    b    c
# 0  1.0  6.0  4.0
# 1  2.0  NaN  NaN
# 2  NaN  NaN  NaN
# 3  NaN  3.4  NaN

# %% [markdown]
# ##### Using a Threshold

# %%
df = pd.DataFrame(np.random.randn(7, 3))

# %%
df.loc[:4, 0] = np.nan
df.iloc[:2, 2] = np.nan

# %%
df[3] = [np.nan, 4, 4, 4, 4, 4, 4]

# %%
df
# Out:
#           0         1         2    3
# 0       NaN  0.610860       NaN  NaN
# 1       NaN  1.704643       NaN  4.0
# 2       NaN -1.713519 -0.448814  4.0
# 3       NaN -0.283682 -0.318860  4.0
# 4       NaN -0.900964 -1.913339  4.0
# 5 -0.339258  1.616071  0.396019  4.0
# 6  0.272042  0.371895 -0.297827  4.0

# %%
df.dropna()
# Out:
#           0         1         2    3
# 5 -0.339258  1.616071  0.396019  4.0
# 6  0.272042  0.371895 -0.297827  4.0

# %%
#2 missing values
df.dropna(thresh = 2)
# Out:
#           0         1         2    3
# 1       NaN  1.704643       NaN  4.0
# 2       NaN -1.713519 -0.448814  4.0
# 3       NaN -0.283682 -0.318860  4.0
# 4       NaN -0.900964 -1.913339  4.0
# 5 -0.339258  1.616071  0.396019  4.0
# 6  0.272042  0.371895 -0.297827  4.0

# %%
#fill missing values
df.fillna(1)
# Out:
#           0         1         2    3
# 0  5.000000 -0.259634  5.000000  1.0
# 1  5.000000  0.157162  5.000000  4.0
# 2  5.000000 -0.869687 -0.173139  4.0
# 3  5.000000 -0.441937  0.084785  4.0
# 4  5.000000  0.538065 -0.578755  4.0
# 5 -0.032205  0.053763  1.410522  4.0
# 6 -1.420466 -0.632809 -1.074498  4.0

# %%
#map to given columns
df.fillna({0: 0.2, 1: 4})
# Out:
#           0         1         2
# 0  0.200000 -0.259634       NaN
# 1  0.200000  0.157162       NaN
# 2  0.200000 -0.869687 -0.173139
# 3  0.200000 -0.441937  0.084785
# 4  0.200000  0.538065 -0.578755
# 5 -0.032205  0.053763  1.410522
# 6 -1.420466 -0.632809 -1.074498

# %%
df
# Out:
#           0         1         2
# 0       NaN -0.259634       NaN
# 1       NaN  0.157162       NaN
# 2       NaN -0.869687 -0.173139
# 3       NaN -0.441937  0.084785
# 4       NaN  0.538065 -0.578755
# 5 -0.032205  0.053763  1.410522
# 6 -1.420466 -0.632809 -1.074498

# %%
#make changes permanent
df.fillna(5, inplace = True)

# %%
df
# Out:
#           0         1         2
# 0  5.000000 -0.259634  5.000000
# 1  5.000000  0.157162  5.000000
# 2  5.000000 -0.869687 -0.173139
# 3  5.000000 -0.441937  0.084785
# 4  5.000000  0.538065 -0.578755
# 5 -0.032205  0.053763  1.410522
# 6 -1.420466 -0.632809 -1.074498

# %% [markdown]
# ### PROBLEMS

# %% [markdown]
# 1. What is the average completion time for these projects?
# 2. Time by borough?
# 3. Drop missing data from `latitude` and `longitude` columns, save data to `house_map_data`.
# 4. Fill in missing values in the `project_completion_date` the given boroughs average completion time for non-null values.

# %%
houses = pd.read_json('https://data.cityofnewyork.us/resource/hg8x-zxpr.json')

# %%
houses.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 42 columns):
# project_id                       1000 non-null int64
# project_name                     1000 non-null object
# program_group                    1000 non-null object
# project_start_date               1000 non-null object
# project_completion_date          431 non-null object
# building_id                      857 non-null float64
# house_number                     1000 non-null object
# street_name                      1000 non-null object
# borough                          1000 non-null object
# postcode                         850 non-null float64
# bbl                              833 non-null float64
# bin                              713 non-null float64
# community_board                  1000 non-null object
# council_district                 998 non-null float64
# census_tract                     850 non-null float64
# neighborhood_tabulation_area     850 non-null object
# latitude                         850 non-null float64
# longitude                        850 non-null float64
# latitude_internal                827 non-null float64
# longitude_internal               827 non-null float64
# building_completion_date         431 non-null object
# reporting_construction_type      1000 non-null object
# extended_affordability_status    1000 non-null object
# prevailing_wage_status           1000 non-null object
# extremely_low_income_units       1000 non-null int64
# very_low_income_units            1000 non-null int64
# low_income_units                 1000 non-null int64
# moderate_income_units            1000 non-null int64
# middle_income_units              1000 non-null int64
# other_income_units               1000 non-null int64
# studio_units                     1000 non-null int64
# _1_br_units                      1000 non-null int64
# _2_br_units                      1000 non-null int64
# _3_br_units                      1000 non-null int64
# _4_br_units                      1000 non-null int64
# _5_br_units                      1000 non-null int64
# _6_br_units                      1000 non-null int64
# unknown_br_units                 1000 non-null int64
# counted_rental_units             1000 non-null int64
# counted_homeownership_units      1000 non-null int64
# all_counted_units                1000 non-null int64
# total_units                      1000 non-null int64
# dtypes: float64(10), int64(19), object(13)
# memory usage: 328.2+ KB

# %% [markdown]
# ##### Other Important methods
#
# - `.duplicated()`
# - `.drop_duplicates()`
# - `.replace()`

# %%
data
# Out:
#      a    b    c   d
# 0  1.0  6.0  4.0 NaN
# 1  2.0  NaN  NaN NaN
# 2  NaN  NaN  NaN NaN
# 3  NaN  3.4  NaN NaN

# %%
data.duplicated()
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# dtype: bool

# %%
data['a'] = 4

# %%
data
# Out:
#    a    b    c   d
# 0  4  6.0  4.0 NaN
# 1  4  NaN  NaN NaN
# 2  4  NaN  NaN NaN
# 3  4  3.4  NaN NaN

# %%
data.duplicated()
# Out:
# 0    False
# 1    False
# 2     True
# 3    False
# dtype: bool

# %%
data.drop_duplicates()
# Out:
#    a    b    c   d
# 0  4  6.0  4.0 NaN
# 1  4  NaN  NaN NaN
# 3  4  3.4  NaN NaN

# %%
data.replace(6, np.nan)
# Out:
#    a    b    c   d
# 0  4  NaN  4.0 NaN
# 1  4  NaN  NaN NaN
# 2  4  NaN  NaN NaN
# 3  4  3.4  NaN NaN

# %%
data.replace({4: 'hi', 6: 0})
# Out:
#     a    b    c   d
# 0  hi  0.0   hi NaN
# 1  hi  NaN  NaN NaN
# 2  hi  NaN  NaN NaN
# 3  hi  3.4  NaN NaN

# %% [markdown]
# ### Combining data with `merge` and `concat`

# %%
df1 = pd.DataFrame({'key': ['a', 'a', 'a', 'b', 'b', 'b', 'c'],
                   'd1': np.random.randint(0, 10, 7)})

df2 = pd.DataFrame({'key': ['a', 'b', 'd'],
                   'd2': np.random.randint(0, 10, 3)})

# %%
df1
# Out:
#   key  d1
# 0   a   0
# 1   a   1
# 2   a   2
# 3   b   8
# 4   b   0
# 5   b   4
# 6   c   5

# %%
df2
# Out:
#   key  d2
# 0   a   2
# 1   b   1
# 2   d   7

# %%
pd.merge(df1, df2)
# Out:
#   key  d1  d2
# 0   a   0   2
# 1   a   1   2
# 2   a   2   2
# 3   b   8   1
# 4   b   0   1
# 5   b   4   1

# %%
pd.merge(df1, df2, on = 'key')
# Out:
#   key  d1  d2
# 0   a   0   2
# 1   a   1   2
# 2   a   2   2
# 3   b   8   1
# 4   b   0   1
# 5   b   4   1

# %%
df3 = pd.DataFrame({'lkey': ['b', 'a', 'b', 'c', 'c', 'a', 'b'],
                   'd1': np.random.randint(6, 19, 7)})

# %%
df4 = pd.DataFrame({'rkey': ['a', 'b', 'd'],
                   'd2': np.random.randint(3, 5, 3)})

# %%
pd.merge(df3, df4, left_on = 'lkey', right_on = 'rkey')
# Out:
#   lkey  d1 rkey  d2
# 0    b  18    b   4
# 1    b   6    b   4
# 2    b  13    b   4
# 3    a   9    a   3
# 4    a  13    a   3

# %% [markdown]
# <img src = 'merge_a.png' />

# %%
pd.merge(df1, df2)
# Out:
#   key  d1  d2
# 0   a   0   2
# 1   a   1   2
# 2   a   2   2
# 3   b   8   1
# 4   b   0   1
# 5   b   4   1

# %%
pd.merge(df1, df2, how = 'left')
# Out:
#   key  d1   d2
# 0   a   0  2.0
# 1   a   1  2.0
# 2   a   2  2.0
# 3   b   8  1.0
# 4   b   0  1.0
# 5   b   4  1.0
# 6   c   5  NaN

# %%
pd.merge(df1, df2, how = 'right')
# Out:
#   key   d1  d2
# 0   a  0.0   2
# 1   a  1.0   2
# 2   a  2.0   2
# 3   b  8.0   1
# 4   b  0.0   1
# 5   b  4.0   1
# 6   d  NaN   7

# %%
pd.merge(df1, df2, how = 'inner')
# Out:
#   key  d1  d2
# 0   a   0   2
# 1   a   1   2
# 2   a   2   2
# 3   b   8   1
# 4   b   0   1
# 5   b   4   1

# %%
pd.merge(df1, df2, how = 'outer')
# Out:
#   key   d1   d2
# 0   a  0.0  2.0
# 1   a  1.0  2.0
# 2   a  2.0  2.0
# 3   b  8.0  1.0
# 4   b  0.0  1.0
# 5   b  4.0  1.0
# 6   c  5.0  NaN
# 7   d  NaN  7.0

# %% [markdown]
# ##### Summary
#
# - `inner`  : Use only the key combinations observed in both tables
# - `left`  : Use all key combinations found in the left table
# - `right`  : Use all key combinations found in the right table
# - `outer`  : Use all key combinations observed in both tables together

# %% [markdown]
# ##### PROBLEMS
#
# 1. Read in the `species.csv` and `surveys.csv` data files located in the `data` directory.
# 2. Create a `DataFrame` called `v_stack` that vertically stacks the datasets.
# 3. Create a `DataFrame` called `h_stack` that horizontally stacks the datasets.
# 4. Read in the `speciesSubset.csv` file, and join this with the survey data using the `species_id` as the left and right key.
# 5. Use the `speciesSubset.csv` file, and join this with the survey data using the `species_id` as the left and right key and using `left` join.
